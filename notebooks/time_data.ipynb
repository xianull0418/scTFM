# %%
# %config Completer.use_jedi = False
import sys, IPython
print("IPython version:", IPython.__version__)
import jedi
print("Jedi version:", jedi.__version__)
# Out:
# IPython version: 9.8.0
# Jedi version: 0.19.2

# %%
import sys
import os
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad
import tiledbsoma
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "/fast/data/scTFM/ae/tiledb_all/SRX25263847"

# %%
experiment = tiledbsoma.Experiment.open(path)
ms = experiment.ms["RNA"]
ms
# Out:
# <Measurement 'file:///fast/data/scTFM/ae/tiledb_all/SRX25263847/ms/RNA' (open for 'r') (3 items)
#     'X': 'file:///fast/data/scTFM/ae/tiledb_all/SRX25263847/ms/RNA/X' (unopened)
#     'uns': 'file:///fast/data/scTFM/ae/tiledb_all/SRX25263847/ms/RNA/uns' (unopened)
#     'var': 'file:///fast/data/scTFM/ae/tiledb_all/SRX25263847/ms/RNA/var' (unopened)>

# %%
# 从实验对象读取obs数据
obs_df = experiment.obs.read().concat().to_pandas()
print(f"细胞观测数据加载完成: {obs_df.shape}")
print("列名:", list(obs_df.columns))
obs_df.head()
# Out:
# 细胞观测数据加载完成: (11495, 7)
# 列名: ['soma_joinid', 'obs_id', 'gene_count', 'umi_count', 'SRX_accession', 'n_genes', 'split_label']
#    soma_joinid            obs_id  gene_count  umi_count SRX_accession  \
# 0            0  AAACCCAAGGTCTACT        2699     6287.0   SRX25263847
# 1            1  AAACCCACAAGCTGCC        2442     7230.0   SRX25263847
# 2            2  AAACCCACAGAGGTTG        1732     3327.0   SRX25263847
# 3            3  AAACCCACAGGTGTTT         705     1392.0   SRX25263847
# 4            4  AAACCCAGTGCATTAC         759      988.0   SRX25263847
#
#    n_genes  split_label
# 0     2699            0
# 1     2442            0
# 2     1732            0
# 3      705            0
# 4      759            0

# %%
raw_path = "/fast/data/scTFM/ae/SRX25263847.h5ad"

adata = sc.read_h5ad(raw_path)
adata
# Out:
# AnnData object with n_obs × n_vars = 11530 × 36601
#     obs: 'gene_count', 'umi_count', 'SRX_accession'
#     var: 'gene_symbols', 'feature_types'

# %%
raw_path = "/fast/data/scTFM/rtf/TEDD/raw/Tedd_8_AdultVagina_scatac.h5ad"

adata = sc.read_h5ad(raw_path)
adata
# Out:
# AnnData object with n_obs × n_vars = 4824 × 13498
#     obs: 'Tissue', 'Celltype', 'Timepoint', 'Sex', 'UMAP_1', 'UMAP_2'
#     uns: 'Cell', 'PMID_DOI', 'Project', 'Sequencing', 'Species', 'Stage', 'Technology', 'Timepoint', 'Tissue'

# %%
SAMPLE_ID = "hs_AD_Brain_Medulla_Organoid__36_e"
SOMA_URI = f"/fast/data/scTFM/rtf/TEDD/tile_4000_fix.uniformUnitStart/{SAMPLE_ID}"

# %%
experiment = tiledbsoma.Experiment.open(SOMA_URI)
ms = experiment.ms['RNA']
list(ms.keys())
# Out:
# ['X', 'obsm', 'obsp', 'uns', 'var', 'varm']

# %%
rna = experiment.ms["RNA"]
rna
# Out:
# <Measurement 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix.uniformUnitStart/hs_AD_Brain_Medulla_Organoid__36_e/ms/RNA' (open for 'r') (6 items)
#     'X': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix.uniformUnitStart/hs_AD_Brain_Medulla_Organoid__36_e/ms/RNA/X' (unopened)
#     'obsm': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix.uniformUnitStart/hs_AD_Brain_Medulla_Organoid__36_e/ms/RNA/obsm' (unopened)
#     'obsp': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix.uniformUnitStart/hs_AD_Brain_Medulla_Organoid__36_e/ms/RNA/obsp' (unopened)
#     'uns': Collection 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix.uniformUnitStart/hs_AD_Brain_Medulla_Organoid__36_e/ms/RNA/uns' (open for 'r') (3 items)
#         'log1p': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix.uniformUnitStart/hs_AD_Brain_Medulla_Organoid__36_e/ms/RNA/uns/log1p' (unopened)
#         'neighbors': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix.uniformUnitStart/hs_AD_Brain_Medulla_Organoid__36_e/ms/RNA/uns/neighbors' (unopened)
#         'pca': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix.uniformUnitStart/hs_AD_Brain_Medulla_Organoid__36_e/ms/RNA/uns/pca' (unopened)
#     'var': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix.uniformUnitStart/hs_AD_Brain_Medulla_Organoid__36_e/ms/RNA/var' (unopened)
#     'varm': 'file:///fast/data/scTFM/rtf/TEDD/tile_4000_fix.uniformUnitStart/hs_AD_Brain_Medulla_Organoid__36_e/ms/RNA/varm' (unopened)>

# %%
obs_df = experiment.obs.read().concat().to_pandas()
obs_df
# Out:
#       soma_joinid                                          new_index  \
# 0               0  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 1               1  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 2               2  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 3               3  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 4               4  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# ...           ...                                                ...
# 6487         6487  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 6488         6488  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 6489         6489  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 6490         6490  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 6491         6491  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
#
#                Tissue                Celltype Timepoint     Sex      UMAP1  \
# 0     cerebral cortex  cerebral cortex neuron   40y-49y  Female  11.686515
# 1     cerebral cortex  cerebral cortex neuron   40y-49y  Female  11.609229
# 2     cerebral cortex  cerebral cortex neuron   40y-49y  Female  11.496363
# 3     cerebral cortex  cerebral cortex neuron   40y-49y  Female  14.068149
# 4     cerebral cortex  cerebral cortex neuron   40y-49y  Female  11.412722
# ...               ...                     ...       ...     ...        ...
# 6487  cerebral cortex               astrocyte   50y-59y  Female   1.235232
# 6488  cerebral cortex              glial cell   50y-59y  Female  -0.727559
# 6489  cerebral cortex              glial cell   50y-59y  Female  -1.646747
# 6490  cerebral cortex              glial cell   50y-59y  Female  -1.063324
# 6491  cerebral cortex              glial cell   50y-59y  Female   0.021754
#
#           UMAP2     time  n_genes  n_counts  \
# 0     14.162333  16508.0     2849    9078.0
# 1     13.596688  16508.0     2643    7460.0
# 2     13.532730  16508.0     2993    8930.0
# 3     17.303436  16508.0     2714    8097.0
# 4     13.144131  16508.0     2761    8178.0
# ...         ...      ...      ...       ...
# 6487   8.057819  20158.0     1094    2728.0
# 6488   6.965711  20158.0     6507   45138.0
# 6489  10.710582  20158.0     4959   28886.0
# 6490   6.900711  20158.0     4661   31304.0
# 6491  10.715168  20158.0     5059   24742.0
#
#                                            next_cell_id  \
# 0     hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 1     hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 2     hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 3     hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 4     hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# ...                                                 ...
# 6487  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 6488  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 6489  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 6490  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 6491  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
#
#       next_cell_probability  \
# 0                  0.697389
# 1                  0.345904
# 2                  0.787357
# 3                  0.431222
# 4                  0.799665
# ...                     ...
# 6487               0.797220
# 6488               0.800000
# 6489               0.800000
# 6490               0.800000
# 6491               0.764283
#
#                                            prev_cell_id  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 6487  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 6488  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 6489  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 6490  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
# 6491  hs_AD_Brain_Medulla_Organoid__36_e_homosapiens...
#
#       prev_cell_probability  split_label
# 0                  0.000000            0
# 1                  0.000000            0
# 2                  0.000000            0
# 3                  0.000000            0
# 4                  0.000000            0
# ...                     ...          ...
# 6487               0.800000            0
# 6488               0.800000            0
# 6489               0.800000            0
# 6490               0.337287            0
# 6491               0.800000            0
#
# [6492 rows x 16 columns]

# %%
uns_df = ms["uns"].read().concat().to_pandas()
uns_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 uns_df = ms["uns"].read().concat().to_pandas()
#       2 uns_df
#
# AttributeError: 'Collection' object has no attribute 'read'

# %%
uns_collection = ms["uns"]
for key in uns_collection.keys():
    obj = uns_collection[key]
    print(f"Key: {key}, Type: {type(obj)}")
# Out:
# Key: log1p, Type: <class 'tiledbsoma._collection.Collection'>
# Key: neighbors, Type: <class 'tiledbsoma._collection.Collection'>
# Key: pca, Type: <class 'tiledbsoma._collection.Collection'>
